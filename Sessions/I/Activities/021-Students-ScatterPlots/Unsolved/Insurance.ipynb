# %%
# Import dependencies and set default values
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

matplotlib.rcParams.update({'font.size':18,
                            'figure.facecolor': (1,1,1,1)})
matplotlib.rc('xtick', labelsize=18) 
matplotlib.rc('ytick', labelsize=18)

import sklearn
from sklearn.linear_model import LinearRegression

# %%
# import insurance.csv file and disply the first 5 rows
df = pd.read_csv("insurance.csv")

# %%
#select records where value of 'smoker' column is 'yes' and display first 5 records
#df_smoker = df[ < add filter here. See 014-Instructor-Pastries/Solved for hints>]
df_smoker = df[df['smoker']=='yes']

# %%
# create a model from LinearRegression

model = 

#
X = 
y = 
model.fit(< enter variables here>)
m,b = model.coef_, model.intercept_

ypred = model.predict(<enter variable or variables here>) # produces a y vs x line that uses the points in df.SPEED
Xminmax = [df_smoker.bmi.min(),df_smoker.bmi.max()]

ybound = m[0]*X + b[0] #makes a y vs x line that only uses min and max points
ybound
# Out:
# array([[27913.08818341],
#        [25541.38711334],
#        [48875.39018781],
#        [38814.0744682 ],
#        [33834.97532731],
#        [40287.1807229 ],
#        [39256.00634461],
#        [40434.49134837],
#        [40832.23003714],
#        [45590.36323982],
#        [38666.76384273],
#        [28060.39880888],
#        [37532.47202661],
#        [41252.06531973],
#        [33481.42982618],
#        [20518.09478481],
#        [19840.46590764],
#        [22138.51166498],
#        [23272.8034811 ],
#        [42231.6809791 ],
#        [38077.52134085],
#        [20540.19137863],
#        [32715.41457373],
#        [30756.18325498],
#        [32921.64944939],
#        [16201.89345853],
#        [15244.37439297],
#        [30888.7628179 ],
#        [28097.22646524],
#        [38504.72215471],
#        [27972.01243359],
#        [32995.30476213],
#        [28502.33068529],
#        [12983.15629201],
#        [24083.01192118],
#        [29076.84212462],
#        [31735.79891436],
# ...

# %%
# Plot a scatter plot with text of trendline equation and trendline

fig, ax = plt.subplots(figsize=(10,5))
#Markers https://matplotlib.org/stable/api/markers_api.html
#Scatter documentation : https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html#matplotlib.axes.Axes.scatter

# create a scatterplot of bmi vs charges
ax.scatter(<var>,<var>,s=100,marker='s', # Replace <var> with appropriate arguments
           alpha=0.2,edgecolors='black',c='red')

# Create a text box 
fig.text(...)

# Create a line plot of the best fit line
ax.plot( <var>,<var>,linestyle='dashed',linewidth=2) # Replace <var> with appropriate arguments

ax.set_xlabel("BMI",fontdict={"size":22})
ax.set_ylabel("Charges ($)",fontdict={"size":22})

ax.set_title("BMI vs Insurance charges (smokers)",pad=30) # pad adds spacing between the title and the top of the axes (or plot area)
# Out:
# Text(0.5, 1.0, 'BMI vs Insurance charges (smokers)')
